# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = '../Data/training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0049 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00226, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 0.0015 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00226 to 0.00195, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00195 to 0.00191, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00191 to 0.00185, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00185 to 0.00185, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.8575e-04 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00185 to 0.00177, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.1140e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00177 to 0.00165, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.1053e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00165 to 0.00155, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 6.9899e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss improved from 0.00155 to 0.00146, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 6.0730e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00146 to 0.00130, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 5.4514e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00130 to 0.00117, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 4.8233e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00117 to 0.00107, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 4.5079e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00107 to 0.00104, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 4.2174e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00104 to 0.00102, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 3.8951e-04 - val_loss: 9.3944e-04
#
# Epoch 00015: val_loss improved from 0.00102 to 0.00094, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 3.6491e-04 - val_loss: 9.4050e-04
#
# Epoch 00016: val_loss did not improve from 0.00094
# Epoch 17/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 3.4587e-04 - val_loss: 8.8697e-04
#
# Epoch 00017: val_loss improved from 0.00094 to 0.00089, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 3.3232e-04 - val_loss: 9.0775e-04
#
# Epoch 00018: val_loss did not improve from 0.00089
# Epoch 19/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 3.2872e-04 - val_loss: 8.8129e-04
#
# Epoch 00019: val_loss improved from 0.00089 to 0.00088, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 3.2047e-04 - val_loss: 8.7833e-04
#
# Epoch 00020: val_loss improved from 0.00088 to 0.00088, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 3.0579e-04 - val_loss: 8.9308e-04
#
# Epoch 00021: val_loss did not improve from 0.00088
# Epoch 22/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.8696e-04 - val_loss: 8.3676e-04
#
# Epoch 00022: val_loss improved from 0.00088 to 0.00084, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.8418e-04 - val_loss: 8.1979e-04
#
# Epoch 00023: val_loss improved from 0.00084 to 0.00082, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.7735e-04 - val_loss: 8.5367e-04
#
# Epoch 00024: val_loss did not improve from 0.00082
# Epoch 25/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.6199e-04 - val_loss: 8.3464e-04
#
# Epoch 00025: val_loss did not improve from 0.00082
# Epoch 26/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.5063e-04 - val_loss: 7.9056e-04
#
# Epoch 00026: val_loss improved from 0.00082 to 0.00079, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.5184e-04 - val_loss: 8.2219e-04
#
# Epoch 00027: val_loss did not improve from 0.00079
# Epoch 28/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.4686e-04 - val_loss: 7.9853e-04
#
# Epoch 00028: val_loss did not improve from 0.00079
# Epoch 29/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.4350e-04 - val_loss: 8.5216e-04
#
# Epoch 00029: val_loss did not improve from 0.00079
# Epoch 30/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.4759e-04 - val_loss: 8.0119e-04
#
# Epoch 00030: val_loss did not improve from 0.00079
# Epoch 31/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.3286e-04 - val_loss: 8.3444e-04
#
# Epoch 00031: val_loss did not improve from 0.00079
# Epoch 32/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.2045e-04 - val_loss: 7.6909e-04
#
# Epoch 00032: val_loss improved from 0.00079 to 0.00077, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.1812e-04 - val_loss: 8.2665e-04
#
# Epoch 00033: val_loss did not improve from 0.00077
# Epoch 34/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.1891e-04 - val_loss: 7.8976e-04
#
# Epoch 00034: val_loss did not improve from 0.00077
# Epoch 35/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.1422e-04 - val_loss: 8.5029e-04
#
# Epoch 00035: val_loss did not improve from 0.00077
# Epoch 36/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.1319e-04 - val_loss: 7.9191e-04
#
# Epoch 00036: val_loss did not improve from 0.00077
# Epoch 37/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 2.0279e-04 - val_loss: 7.6168e-04
#
# Epoch 00037: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.9929e-04 - val_loss: 8.0894e-04
#
# Epoch 00038: val_loss did not improve from 0.00076
# Epoch 39/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.9800e-04 - val_loss: 8.4042e-04
#
# Epoch 00039: val_loss did not improve from 0.00076
# Epoch 40/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.9440e-04 - val_loss: 8.2677e-04
#
# Epoch 00040: val_loss did not improve from 0.00076
# Epoch 41/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.9604e-04 - val_loss: 8.0217e-04
#
# Epoch 00041: val_loss did not improve from 0.00076
# Epoch 42/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.8913e-04 - val_loss: 7.6230e-04
#
# Epoch 00042: val_loss did not improve from 0.00076
# Epoch 43/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.8371e-04 - val_loss: 7.7896e-04
#
# Epoch 00043: val_loss did not improve from 0.00076
# Epoch 44/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.8255e-04 - val_loss: 7.8847e-04
#
# Epoch 00044: val_loss did not improve from 0.00076
# Epoch 45/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.8382e-04 - val_loss: 7.5205e-04
#
# Epoch 00045: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 46/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.8790e-04 - val_loss: 7.8408e-04
#
# Epoch 00046: val_loss did not improve from 0.00075
# Epoch 47/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.7652e-04 - val_loss: 8.4152e-04
#
# Epoch 00047: val_loss did not improve from 0.00075
# Epoch 48/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.7759e-04 - val_loss: 7.8400e-04
#
# Epoch 00048: val_loss did not improve from 0.00075
# Epoch 49/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.7372e-04 - val_loss: 7.8677e-04
#
# Epoch 00049: val_loss did not improve from 0.00075
# Epoch 50/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.6727e-04 - val_loss: 7.6586e-04
#
# Epoch 00050: val_loss did not improve from 0.00075
# Epoch 51/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.6962e-04 - val_loss: 7.5067e-04
#
# Epoch 00051: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 52/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.6724e-04 - val_loss: 7.5164e-04
#
# Epoch 00052: val_loss did not improve from 0.00075
# Epoch 53/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.6537e-04 - val_loss: 7.6961e-04
#
# Epoch 00053: val_loss did not improve from 0.00075
# Epoch 54/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.6473e-04 - val_loss: 8.0917e-04
#
# Epoch 00054: val_loss did not improve from 0.00075
# Epoch 55/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.5827e-04 - val_loss: 7.5237e-04
#
# Epoch 00055: val_loss did not improve from 0.00075
# Epoch 56/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.6540e-04 - val_loss: 7.8290e-04
#
# Epoch 00056: val_loss did not improve from 0.00075
# Epoch 57/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.5614e-04 - val_loss: 7.8333e-04
#
# Epoch 00057: val_loss did not improve from 0.00075
# Epoch 58/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.5584e-04 - val_loss: 7.4896e-04
#
# Epoch 00058: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 59/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.5583e-04 - val_loss: 8.1599e-04
#
# Epoch 00059: val_loss did not improve from 0.00075
# Epoch 60/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.5216e-04 - val_loss: 7.7579e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
# Epoch 61/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.5084e-04 - val_loss: 7.3517e-04
#
# Epoch 00061: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 62/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.4766e-04 - val_loss: 7.4581e-04
#
# Epoch 00062: val_loss did not improve from 0.00074
# Epoch 63/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.4222e-04 - val_loss: 7.9373e-04
#
# Epoch 00063: val_loss did not improve from 0.00074
# Epoch 64/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.4331e-04 - val_loss: 7.6770e-04
#
# Epoch 00064: val_loss did not improve from 0.00074
# Epoch 65/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.4637e-04 - val_loss: 7.3544e-04
#
# Epoch 00065: val_loss did not improve from 0.00074
# Epoch 66/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.4132e-04 - val_loss: 7.8135e-04
#
# Epoch 00066: val_loss did not improve from 0.00074
# Epoch 67/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.4416e-04 - val_loss: 8.2342e-04
#
# Epoch 00067: val_loss did not improve from 0.00074
# Epoch 68/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.4410e-04 - val_loss: 7.4423e-04
#
# Epoch 00068: val_loss did not improve from 0.00074
# Epoch 69/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.3966e-04 - val_loss: 8.0151e-04
#
# Epoch 00069: val_loss did not improve from 0.00074
# Epoch 70/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.3899e-04 - val_loss: 7.4691e-04
#
# Epoch 00070: val_loss did not improve from 0.00074
# Epoch 71/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.4000e-04 - val_loss: 7.8853e-04
#
# Epoch 00071: val_loss did not improve from 0.00074
# Epoch 72/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.3802e-04 - val_loss: 7.4982e-04
#
# Epoch 00072: val_loss did not improve from 0.00074
# Epoch 73/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.3484e-04 - val_loss: 7.2835e-04
#
# Epoch 00073: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 74/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.3598e-04 - val_loss: 7.4848e-04
#
# Epoch 00074: val_loss did not improve from 0.00073
# Epoch 75/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.3290e-04 - val_loss: 7.4418e-04
#
# Epoch 00075: val_loss did not improve from 0.00073
# Epoch 76/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.3059e-04 - val_loss: 7.4141e-04
#
# Epoch 00076: val_loss did not improve from 0.00073
# Epoch 77/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.3996e-04 - val_loss: 7.6559e-04
#
# Epoch 00077: val_loss did not improve from 0.00073
# Epoch 78/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.3013e-04 - val_loss: 7.3896e-04
#
# Epoch 00078: val_loss did not improve from 0.00073
# Epoch 79/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.2928e-04 - val_loss: 7.8513e-04
#
# Epoch 00079: val_loss did not improve from 0.00073
# Epoch 80/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.3122e-04 - val_loss: 7.5397e-04
#
# Epoch 00080: val_loss did not improve from 0.00073
# Epoch 81/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.2930e-04 - val_loss: 7.8094e-04
#
# Epoch 00081: val_loss did not improve from 0.00073
# Epoch 82/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.2431e-04 - val_loss: 7.6346e-04
#
# Epoch 00082: val_loss did not improve from 0.00073
# Epoch 83/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.2040e-04 - val_loss: 7.5389e-04
#
# Epoch 00083: val_loss did not improve from 0.00073
# Epoch 84/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.2257e-04 - val_loss: 7.6027e-04
#
# Epoch 00084: val_loss did not improve from 0.00073
# Epoch 85/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.2259e-04 - val_loss: 7.6011e-04
#
# Epoch 00085: val_loss did not improve from 0.00073
# Epoch 86/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.2065e-04 - val_loss: 8.1373e-04
#
# Epoch 00086: val_loss did not improve from 0.00073
# Epoch 87/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.1712e-04 - val_loss: 7.6257e-04
#
# Epoch 00087: val_loss did not improve from 0.00073
# Epoch 88/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.1971e-04 - val_loss: 7.9649e-04
#
# Epoch 00088: val_loss did not improve from 0.00073
# Epoch 89/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.1803e-04 - val_loss: 7.8192e-04
#
# Epoch 00089: val_loss did not improve from 0.00073
# Epoch 90/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.2023e-04 - val_loss: 7.7418e-04
#
# Epoch 00090: val_loss did not improve from 0.00073
# Epoch 91/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.1497e-04 - val_loss: 7.6696e-04
#
# Epoch 00091: val_loss did not improve from 0.00073
# Epoch 92/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.1384e-04 - val_loss: 7.9600e-04
#
# Epoch 00092: val_loss did not improve from 0.00073
# Epoch 93/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0871e-04 - val_loss: 7.7558e-04
#
# Epoch 00093: val_loss did not improve from 0.00073
# Epoch 94/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.1081e-04 - val_loss: 7.7514e-04
#
# Epoch 00094: val_loss did not improve from 0.00073
# Epoch 95/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.1189e-04 - val_loss: 7.8119e-04
#
# Epoch 00095: val_loss did not improve from 0.00073
# Epoch 96/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.1404e-04 - val_loss: 7.6808e-04
#
# Epoch 00096: val_loss did not improve from 0.00073
# Epoch 97/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0976e-04 - val_loss: 7.4870e-04
#
# Epoch 00097: val_loss did not improve from 0.00073
# Epoch 98/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0782e-04 - val_loss: 7.7736e-04
#
# Epoch 00098: val_loss did not improve from 0.00073
# Epoch 99/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.1051e-04 - val_loss: 7.7719e-04
#
# Epoch 00099: val_loss did not improve from 0.00073
# Epoch 100/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0652e-04 - val_loss: 7.7694e-04
#
# Epoch 00100: val_loss did not improve from 0.00073
# Epoch 101/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0840e-04 - val_loss: 7.5972e-04
#
# Epoch 00101: val_loss did not improve from 0.00073
# Epoch 102/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0784e-04 - val_loss: 7.6644e-04
#
# Epoch 00102: val_loss did not improve from 0.00073
# Epoch 103/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0604e-04 - val_loss: 7.9231e-04
#
# Epoch 00103: val_loss did not improve from 0.00073
# Epoch 104/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0385e-04 - val_loss: 7.6709e-04
#
# Epoch 00104: val_loss did not improve from 0.00073
# Epoch 105/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0245e-04 - val_loss: 8.2376e-04
#
# Epoch 00105: val_loss did not improve from 0.00073
# Epoch 106/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0463e-04 - val_loss: 8.3689e-04
#
# Epoch 00106: val_loss did not improve from 0.00073
# Epoch 107/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0376e-04 - val_loss: 7.9171e-04
#
# Epoch 00107: val_loss did not improve from 0.00073
# Epoch 108/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0472e-04 - val_loss: 7.9579e-04
#
# Epoch 00108: val_loss did not improve from 0.00073
# Epoch 109/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0185e-04 - val_loss: 7.7861e-04
#
# Epoch 00109: val_loss did not improve from 0.00073
# Epoch 110/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0574e-04 - val_loss: 8.0098e-04
#
# Epoch 00110: val_loss did not improve from 0.00073
# Epoch 111/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 1.0321e-04 - val_loss: 8.0047e-04
#
# Epoch 00111: val_loss did not improve from 0.00073
# Epoch 112/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.6828e-05 - val_loss: 7.9077e-04
#
# Epoch 00112: val_loss did not improve from 0.00073
# Epoch 113/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.8610e-05 - val_loss: 7.6043e-04
#
# Epoch 00113: val_loss did not improve from 0.00073
# Epoch 114/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.8856e-05 - val_loss: 7.9062e-04
#
# Epoch 00114: val_loss did not improve from 0.00073
# Epoch 115/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.6688e-05 - val_loss: 7.9189e-04
#
# Epoch 00115: val_loss did not improve from 0.00073
# Epoch 116/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.5121e-05 - val_loss: 7.8915e-04
#
# Epoch 00116: val_loss did not improve from 0.00073
# Epoch 117/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.6361e-05 - val_loss: 7.8871e-04
#
# Epoch 00117: val_loss did not improve from 0.00073
# Epoch 118/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.6355e-05 - val_loss: 7.5393e-04
#
# Epoch 00118: val_loss did not improve from 0.00073
# Epoch 119/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.4741e-05 - val_loss: 7.8444e-04
#
# Epoch 00119: val_loss did not improve from 0.00073
# Epoch 120/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.4020e-05 - val_loss: 7.3615e-04
#
# Epoch 00120: val_loss did not improve from 0.00073
# Epoch 121/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.3765e-05 - val_loss: 7.8594e-04
#
# Epoch 00121: val_loss did not improve from 0.00073
# Epoch 122/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.3454e-05 - val_loss: 7.9970e-04
#
# Epoch 00122: val_loss did not improve from 0.00073
# Epoch 123/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.2828e-05 - val_loss: 7.8042e-04
#
# Epoch 00123: val_loss did not improve from 0.00073
# Epoch 124/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.4302e-05 - val_loss: 7.9388e-04
#
# Epoch 00124: val_loss did not improve from 0.00073
# Epoch 125/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.3160e-05 - val_loss: 7.8989e-04
#
# Epoch 00125: val_loss did not improve from 0.00073
# Epoch 126/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.4441e-05 - val_loss: 7.8101e-04
#
# Epoch 00126: val_loss did not improve from 0.00073
# Epoch 127/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.2008e-05 - val_loss: 7.5218e-04
#
# Epoch 00127: val_loss did not improve from 0.00073
# Epoch 128/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.0501e-05 - val_loss: 7.8637e-04
#
# Epoch 00128: val_loss did not improve from 0.00073
# Epoch 129/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 9.0738e-05 - val_loss: 7.8549e-04
#
# Epoch 00129: val_loss did not improve from 0.00073
# Epoch 130/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.7216e-05 - val_loss: 7.6160e-04
#
# Epoch 00130: val_loss did not improve from 0.00073
# Epoch 131/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.6556e-05 - val_loss: 7.6854e-04
#
# Epoch 00131: val_loss did not improve from 0.00073
# Epoch 132/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.7594e-05 - val_loss: 8.0302e-04
#
# Epoch 00132: val_loss did not improve from 0.00073
# Epoch 133/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.6749e-05 - val_loss: 7.7386e-04
#
# Epoch 00133: val_loss did not improve from 0.00073
# Epoch 134/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.3762e-05 - val_loss: 7.6970e-04
#
# Epoch 00134: val_loss did not improve from 0.00073
# Epoch 135/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.5281e-05 - val_loss: 7.5230e-04
#
# Epoch 00135: val_loss did not improve from 0.00073
# Epoch 136/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.8613e-05 - val_loss: 8.0869e-04
#
# Epoch 00136: val_loss did not improve from 0.00073
# Epoch 137/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.7573e-05 - val_loss: 7.8565e-04
#
# Epoch 00137: val_loss did not improve from 0.00073
# Epoch 138/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.3564e-05 - val_loss: 7.9695e-04
#
# Epoch 00138: val_loss did not improve from 0.00073
# Epoch 139/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.6636e-05 - val_loss: 7.5443e-04
#
# Epoch 00139: val_loss did not improve from 0.00073
# Epoch 140/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.6014e-05 - val_loss: 7.9262e-04
#
# Epoch 00140: val_loss did not improve from 0.00073
# Epoch 141/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.3073e-05 - val_loss: 7.9651e-04
#
# Epoch 00141: val_loss did not improve from 0.00073
# Epoch 142/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.0276e-05 - val_loss: 7.9144e-04
#
# Epoch 00142: val_loss did not improve from 0.00073
# Epoch 143/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.2878e-05 - val_loss: 7.8126e-04
#
# Epoch 00143: val_loss did not improve from 0.00073
# Epoch 144/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.2944e-05 - val_loss: 7.7069e-04
#
# Epoch 00144: val_loss did not improve from 0.00073
# Epoch 145/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.2257e-05 - val_loss: 7.4154e-04
#
# Epoch 00145: val_loss did not improve from 0.00073
# Epoch 146/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.1382e-05 - val_loss: 7.6935e-04
#
# Epoch 00146: val_loss did not improve from 0.00073
# Epoch 147/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.0483e-05 - val_loss: 7.7395e-04
#
# Epoch 00147: val_loss did not improve from 0.00073
# Epoch 148/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.1602e-05 - val_loss: 7.9408e-04
#
# Epoch 00148: val_loss did not improve from 0.00073
# Epoch 149/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.1404e-05 - val_loss: 7.8017e-04
#
# Epoch 00149: val_loss did not improve from 0.00073
# Epoch 150/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 8.0183e-05 - val_loss: 8.0205e-04
#
# Epoch 00150: val_loss did not improve from 0.00073

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = '../Data/test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)

# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 5s 1ms/step - loss: 0.0047 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00199, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00199 to 0.00185, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00185 to 0.00181, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.9291e-04 - val_loss: 0.0015
#
# Epoch 00004: val_loss improved from 0.00181 to 0.00151, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 6.4418e-04 - val_loss: 0.0012
#
# Epoch 00005: val_loss improved from 0.00151 to 0.00122, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 5.4507e-04 - val_loss: 9.9788e-04
#
# Epoch 00006: val_loss improved from 0.00122 to 0.00100, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 4.7416e-04 - val_loss: 8.9798e-04
#
# Epoch 00007: val_loss improved from 0.00100 to 0.00090, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 4.2463e-04 - val_loss: 8.7140e-04
#
# Epoch 00008: val_loss improved from 0.00090 to 0.00087, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 3.8829e-04 - val_loss: 7.9697e-04
#
# Epoch 00009: val_loss improved from 0.00087 to 0.00080, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 3.5956e-04 - val_loss: 8.0665e-04
#
# Epoch 00010: val_loss did not improve from 0.00080
# Epoch 11/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 3.3885e-04 - val_loss: 7.9092e-04
#
# Epoch 00011: val_loss improved from 0.00080 to 0.00079, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 3.1561e-04 - val_loss: 7.3111e-04
#
# Epoch 00012: val_loss improved from 0.00079 to 0.00073, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 3.0756e-04 - val_loss: 6.9895e-04
#
# Epoch 00013: val_loss improved from 0.00073 to 0.00070, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.8937e-04 - val_loss: 7.0504e-04
#
# Epoch 00014: val_loss did not improve from 0.00070
# Epoch 15/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.7345e-04 - val_loss: 7.0609e-04
#
# Epoch 00015: val_loss did not improve from 0.00070
# Epoch 16/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.7394e-04 - val_loss: 6.8856e-04
#
# Epoch 00016: val_loss improved from 0.00070 to 0.00069, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.6170e-04 - val_loss: 6.9823e-04
#
# Epoch 00017: val_loss did not improve from 0.00069
# Epoch 18/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.5718e-04 - val_loss: 6.5544e-04
#
# Epoch 00018: val_loss improved from 0.00069 to 0.00066, saving model to best_weights_augment.h5
# Epoch 19/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.4271e-04 - val_loss: 6.5067e-04
#
# Epoch 00019: val_loss improved from 0.00066 to 0.00065, saving model to best_weights_augment.h5
# Epoch 20/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.4022e-04 - val_loss: 6.4690e-04
#
# Epoch 00020: val_loss improved from 0.00065 to 0.00065, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.3074e-04 - val_loss: 6.5426e-04
#
# Epoch 00021: val_loss did not improve from 0.00065
# Epoch 22/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.2477e-04 - val_loss: 6.5611e-04
#
# Epoch 00022: val_loss did not improve from 0.00065
# Epoch 23/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.1876e-04 - val_loss: 6.6052e-04
#
# Epoch 00023: val_loss did not improve from 0.00065
# Epoch 24/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.1457e-04 - val_loss: 6.4055e-04
#
# Epoch 00024: val_loss improved from 0.00065 to 0.00064, saving model to best_weights_augment.h5
# Epoch 25/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.2293e-04 - val_loss: 6.6522e-04
#
# Epoch 00025: val_loss did not improve from 0.00064
# Epoch 26/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.0811e-04 - val_loss: 6.4740e-04
#
# Epoch 00026: val_loss did not improve from 0.00064
# Epoch 27/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.0085e-04 - val_loss: 6.3153e-04
#
# Epoch 00027: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 28/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 2.0145e-04 - val_loss: 6.4862e-04
#
# Epoch 00028: val_loss did not improve from 0.00063
# Epoch 29/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.9363e-04 - val_loss: 6.4202e-04
#
# Epoch 00029: val_loss did not improve from 0.00063
# Epoch 30/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.8911e-04 - val_loss: 6.4520e-04
#
# Epoch 00030: val_loss did not improve from 0.00063
# Epoch 31/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.9103e-04 - val_loss: 6.5177e-04
#
# Epoch 00031: val_loss did not improve from 0.00063
# Epoch 32/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.8510e-04 - val_loss: 6.3552e-04
#
# Epoch 00032: val_loss did not improve from 0.00063
# Epoch 33/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.8032e-04 - val_loss: 6.1748e-04
#
# Epoch 00033: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 34/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.7637e-04 - val_loss: 6.6683e-04
#
# Epoch 00034: val_loss did not improve from 0.00062
# Epoch 35/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.7565e-04 - val_loss: 6.1779e-04
#
# Epoch 00035: val_loss did not improve from 0.00062
# Epoch 36/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.7430e-04 - val_loss: 6.3562e-04
#
# Epoch 00036: val_loss did not improve from 0.00062
# Epoch 37/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.6913e-04 - val_loss: 6.3050e-04
#
# Epoch 00037: val_loss did not improve from 0.00062
# Epoch 38/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.6634e-04 - val_loss: 6.3447e-04
#
# Epoch 00038: val_loss did not improve from 0.00062
# Epoch 39/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.5807e-04 - val_loss: 6.1971e-04
#
# Epoch 00039: val_loss did not improve from 0.00062
# Epoch 40/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.6168e-04 - val_loss: 6.4142e-04
#
# Epoch 00040: val_loss did not improve from 0.00062
# Epoch 41/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.5746e-04 - val_loss: 6.2112e-04
#
# Epoch 00041: val_loss did not improve from 0.00062
# Epoch 42/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.5456e-04 - val_loss: 6.1147e-04
#
# Epoch 00042: val_loss improved from 0.00062 to 0.00061, saving model to best_weights_augment.h5
# Epoch 43/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.5359e-04 - val_loss: 6.0416e-04
#
# Epoch 00043: val_loss improved from 0.00061 to 0.00060, saving model to best_weights_augment.h5
# Epoch 44/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.5630e-04 - val_loss: 6.1534e-04
#
# Epoch 00044: val_loss did not improve from 0.00060
# Epoch 45/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.4920e-04 - val_loss: 6.4208e-04
#
# Epoch 00045: val_loss did not improve from 0.00060
# Epoch 46/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.4713e-04 - val_loss: 6.3808e-04
#
# Epoch 00046: val_loss did not improve from 0.00060
# Epoch 47/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.5012e-04 - val_loss: 6.7655e-04
#
# Epoch 00047: val_loss did not improve from 0.00060
# Epoch 48/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.4284e-04 - val_loss: 6.3388e-04
#
# Epoch 00048: val_loss did not improve from 0.00060
# Epoch 49/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.4012e-04 - val_loss: 6.2830e-04
#
# Epoch 00049: val_loss did not improve from 0.00060
# Epoch 50/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.4058e-04 - val_loss: 6.6063e-04
#
# Epoch 00050: val_loss did not improve from 0.00060
# Epoch 51/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.3674e-04 - val_loss: 6.1210e-04
#
# Epoch 00051: val_loss did not improve from 0.00060
# Epoch 52/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.3710e-04 - val_loss: 6.3549e-04
#
# Epoch 00052: val_loss did not improve from 0.00060
# Epoch 53/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.3521e-04 - val_loss: 6.1703e-04
#
# Epoch 00053: val_loss did not improve from 0.00060
# Epoch 54/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.3399e-04 - val_loss: 6.3710e-04
#
# Epoch 00054: val_loss did not improve from 0.00060
# Epoch 55/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.3050e-04 - val_loss: 6.0610e-04
#
# Epoch 00055: val_loss did not improve from 0.00060
# Epoch 56/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.2980e-04 - val_loss: 6.6529e-04
#
# Epoch 00056: val_loss did not improve from 0.00060
# Epoch 57/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.3035e-04 - val_loss: 6.2535e-04
#
# Epoch 00057: val_loss did not improve from 0.00060
# Epoch 58/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.2851e-04 - val_loss: 6.1481e-04
#
# Epoch 00058: val_loss did not improve from 0.00060
# Epoch 59/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.2326e-04 - val_loss: 6.0909e-04
#
# Epoch 00059: val_loss did not improve from 0.00060
# Epoch 60/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.2447e-04 - val_loss: 6.2508e-04
#
# Epoch 00060: val_loss did not improve from 0.00060
# Epoch 61/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.2124e-04 - val_loss: 6.2368e-04
#
# Epoch 00061: val_loss did not improve from 0.00060
# Epoch 62/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.2178e-04 - val_loss: 6.2327e-04
#
# Epoch 00062: val_loss did not improve from 0.00060
# Epoch 63/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.2119e-04 - val_loss: 6.2868e-04
#
# Epoch 00063: val_loss did not improve from 0.00060
# Epoch 64/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.2070e-04 - val_loss: 6.5535e-04
#
# Epoch 00064: val_loss did not improve from 0.00060
# Epoch 65/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.1952e-04 - val_loss: 6.3038e-04
#
# Epoch 00065: val_loss did not improve from 0.00060
# Epoch 66/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.2166e-04 - val_loss: 6.2930e-04
#
# Epoch 00066: val_loss did not improve from 0.00060
# Epoch 67/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.1724e-04 - val_loss: 6.1663e-04
#
# Epoch 00067: val_loss did not improve from 0.00060
# Epoch 68/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.1204e-04 - val_loss: 6.3056e-04
#
# Epoch 00068: val_loss did not improve from 0.00060
# Epoch 69/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.1352e-04 - val_loss: 6.3188e-04
#
# Epoch 00069: val_loss did not improve from 0.00060
# Epoch 70/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.1662e-04 - val_loss: 6.2244e-04
#
# Epoch 00070: val_loss did not improve from 0.00060
# Epoch 71/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.1363e-04 - val_loss: 6.3128e-04
#
# Epoch 00071: val_loss did not improve from 0.00060
# Epoch 72/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.1190e-04 - val_loss: 6.7749e-04
#
# Epoch 00072: val_loss did not improve from 0.00060
# Epoch 73/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.0803e-04 - val_loss: 6.0816e-04
#
# Epoch 00073: val_loss did not improve from 0.00060
# Epoch 74/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.0705e-04 - val_loss: 6.2537e-04
#
# Epoch 00074: val_loss did not improve from 0.00060
# Epoch 75/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.0634e-04 - val_loss: 6.2235e-04
#
# Epoch 00075: val_loss did not improve from 0.00060
# Epoch 76/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.0520e-04 - val_loss: 6.2819e-04
#
# Epoch 00076: val_loss did not improve from 0.00060
# Epoch 77/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.0701e-04 - val_loss: 6.3542e-04
#
# Epoch 00077: val_loss did not improve from 0.00060
# Epoch 78/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.0395e-04 - val_loss: 6.7485e-04
#
# Epoch 00078: val_loss did not improve from 0.00060
# Epoch 79/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.0218e-04 - val_loss: 6.4899e-04
#
# Epoch 00079: val_loss did not improve from 0.00060
# Epoch 80/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.0183e-04 - val_loss: 6.3000e-04
#
# Epoch 00080: val_loss did not improve from 0.00060
# Epoch 81/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.0124e-04 - val_loss: 6.3166e-04
#
# Epoch 00081: val_loss did not improve from 0.00060
# Epoch 82/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.0107e-04 - val_loss: 6.3955e-04
#
# Epoch 00082: val_loss did not improve from 0.00060
# Epoch 83/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.9361e-05 - val_loss: 6.4121e-04
#
# Epoch 00083: val_loss did not improve from 0.00060
# Epoch 84/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 1.0088e-04 - val_loss: 6.3187e-04
#
# Epoch 00084: val_loss did not improve from 0.00060
# Epoch 85/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.8889e-05 - val_loss: 6.4329e-04
#
# Epoch 00085: val_loss did not improve from 0.00060
# Epoch 86/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.9133e-05 - val_loss: 6.2126e-04
#
# Epoch 00086: val_loss did not improve from 0.00060
# Epoch 87/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.7544e-05 - val_loss: 6.5960e-04
#
# Epoch 00087: val_loss did not improve from 0.00060
# Epoch 88/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.7019e-05 - val_loss: 6.3059e-04
#
# Epoch 00088: val_loss did not improve from 0.00060
# Epoch 89/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.4970e-05 - val_loss: 6.2073e-04
#
# Epoch 00089: val_loss did not improve from 0.00060
# Epoch 90/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.4283e-05 - val_loss: 6.3332e-04
#
# Epoch 00090: val_loss did not improve from 0.00060
# Epoch 91/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.3425e-05 - val_loss: 6.2184e-04
#
# Epoch 00091: val_loss did not improve from 0.00060
# Epoch 92/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.1220e-05 - val_loss: 6.4906e-04
#
# Epoch 00092: val_loss did not improve from 0.00060
# Epoch 93/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.4529e-05 - val_loss: 6.3690e-04
#
# Epoch 00093: val_loss did not improve from 0.00060
# Epoch 94/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.2324e-05 - val_loss: 6.2554e-04
#
# Epoch 00094: val_loss did not improve from 0.00060
# Epoch 95/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.2212e-05 - val_loss: 6.1748e-04
#
# Epoch 00095: val_loss did not improve from 0.00060
# Epoch 96/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.2070e-05 - val_loss: 6.3321e-04
#
# Epoch 00096: val_loss did not improve from 0.00060
# Epoch 97/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.1484e-05 - val_loss: 6.1859e-04
#
# Epoch 00097: val_loss did not improve from 0.00060
# Epoch 98/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.1393e-05 - val_loss: 6.2752e-04
#
# Epoch 00098: val_loss did not improve from 0.00060
# Epoch 99/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.0158e-05 - val_loss: 6.4792e-04
#
# Epoch 00099: val_loss did not improve from 0.00060
# Epoch 100/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.2711e-05 - val_loss: 6.1701e-04
#
# Epoch 00100: val_loss did not improve from 0.00060
# Epoch 101/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.8073e-05 - val_loss: 6.3982e-04
#
# Epoch 00101: val_loss did not improve from 0.00060
# Epoch 102/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.1168e-05 - val_loss: 6.1685e-04
#
# Epoch 00102: val_loss did not improve from 0.00060
# Epoch 103/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 9.5109e-05 - val_loss: 6.4702e-04
#
# Epoch 00103: val_loss did not improve from 0.00060
# Epoch 104/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.9759e-05 - val_loss: 6.2241e-04
#
# Epoch 00104: val_loss did not improve from 0.00060
# Epoch 105/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.8182e-05 - val_loss: 6.5883e-04
#
# Epoch 00105: val_loss did not improve from 0.00060
# Epoch 106/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.8296e-05 - val_loss: 6.2586e-04
#
# Epoch 00106: val_loss did not improve from 0.00060
# Epoch 107/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.6175e-05 - val_loss: 6.3939e-04
#
# Epoch 00107: val_loss did not improve from 0.00060
# Epoch 108/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.6677e-05 - val_loss: 6.3222e-04
#
# Epoch 00108: val_loss did not improve from 0.00060
# Epoch 109/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.5393e-05 - val_loss: 6.3146e-04
#
# Epoch 00109: val_loss did not improve from 0.00060
# Epoch 110/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.8413e-05 - val_loss: 6.4105e-04
#
# Epoch 00110: val_loss did not improve from 0.00060
# Epoch 111/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.8187e-05 - val_loss: 6.3786e-04
#
# Epoch 00111: val_loss did not improve from 0.00060
# Epoch 112/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.6358e-05 - val_loss: 6.2461e-04
#
# Epoch 00112: val_loss did not improve from 0.00060
# Epoch 113/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.5965e-05 - val_loss: 6.2812e-04
#
# Epoch 00113: val_loss did not improve from 0.00060
# Epoch 114/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.6723e-05 - val_loss: 6.2045e-04
#
# Epoch 00114: val_loss did not improve from 0.00060
# Epoch 115/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.4509e-05 - val_loss: 6.4152e-04
#
# Epoch 00115: val_loss did not improve from 0.00060
# Epoch 116/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.5061e-05 - val_loss: 6.3116e-04
#
# Epoch 00116: val_loss did not improve from 0.00060
# Epoch 117/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.4560e-05 - val_loss: 6.6381e-04
#
# Epoch 00117: val_loss did not improve from 0.00060
# Epoch 118/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.3595e-05 - val_loss: 6.3431e-04
#
# Epoch 00118: val_loss did not improve from 0.00060
# Epoch 119/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.1427e-05 - val_loss: 6.3024e-04
#
# Epoch 00119: val_loss did not improve from 0.00060
# Epoch 120/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.4704e-05 - val_loss: 6.2086e-04
#
# Epoch 00120: val_loss did not improve from 0.00060
# Epoch 121/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.3836e-05 - val_loss: 6.3693e-04
#
# Epoch 00121: val_loss did not improve from 0.00060
# Epoch 122/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.2302e-05 - val_loss: 6.3416e-04
#
# Epoch 00122: val_loss did not improve from 0.00060
# Epoch 123/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.1623e-05 - val_loss: 6.3174e-04
#
# Epoch 00123: val_loss did not improve from 0.00060
# Epoch 124/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.2680e-05 - val_loss: 6.6649e-04
#
# Epoch 00124: val_loss did not improve from 0.00060
# Epoch 125/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.1455e-05 - val_loss: 6.3262e-04
#
# Epoch 00125: val_loss did not improve from 0.00060
# Epoch 126/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.1687e-05 - val_loss: 6.7617e-04
#
# Epoch 00126: val_loss did not improve from 0.00060
# Epoch 127/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.1560e-05 - val_loss: 6.4974e-04
#
# Epoch 00127: val_loss did not improve from 0.00060
# Epoch 128/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.9068e-05 - val_loss: 6.2640e-04
#
# Epoch 00128: val_loss did not improve from 0.00060
# Epoch 129/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.0831e-05 - val_loss: 6.4418e-04
#
# Epoch 00129: val_loss did not improve from 0.00060
# Epoch 130/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.0120e-05 - val_loss: 6.2275e-04
#
# Epoch 00130: val_loss did not improve from 0.00060
# Epoch 131/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.0078e-05 - val_loss: 6.4660e-04
#
# Epoch 00131: val_loss did not improve from 0.00060
# Epoch 132/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.9154e-05 - val_loss: 6.4176e-04
#
# Epoch 00132: val_loss did not improve from 0.00060
# Epoch 133/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.9337e-05 - val_loss: 6.3155e-04
#
# Epoch 00133: val_loss did not improve from 0.00060
# Epoch 134/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.1901e-05 - val_loss: 6.6029e-04
#
# Epoch 00134: val_loss did not improve from 0.00060
# Epoch 135/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.1625e-05 - val_loss: 6.4519e-04
#
# Epoch 00135: val_loss did not improve from 0.00060
# Epoch 136/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.9598e-05 - val_loss: 6.4160e-04
#
# Epoch 00136: val_loss did not improve from 0.00060
# Epoch 137/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.9369e-05 - val_loss: 6.7554e-04
#
# Epoch 00137: val_loss did not improve from 0.00060
# Epoch 138/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.0521e-05 - val_loss: 6.4757e-04
#
# Epoch 00138: val_loss did not improve from 0.00060
# Epoch 139/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.6831e-05 - val_loss: 6.6687e-04
#
# Epoch 00139: val_loss did not improve from 0.00060
# Epoch 140/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.9033e-05 - val_loss: 6.5061e-04
#
# Epoch 00140: val_loss did not improve from 0.00060
# Epoch 141/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.9330e-05 - val_loss: 6.2671e-04
#
# Epoch 00141: val_loss did not improve from 0.00060
# Epoch 142/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.0126e-05 - val_loss: 6.6182e-04
#
# Epoch 00142: val_loss did not improve from 0.00060
# Epoch 143/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.0177e-05 - val_loss: 6.5558e-04
#
# Epoch 00143: val_loss did not improve from 0.00060
# Epoch 144/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.6840e-05 - val_loss: 6.3689e-04
#
# Epoch 00144: val_loss did not improve from 0.00060
# Epoch 145/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.6804e-05 - val_loss: 6.5290e-04
#
# Epoch 00145: val_loss did not improve from 0.00060
# Epoch 146/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.8718e-05 - val_loss: 6.3976e-04
#
# Epoch 00146: val_loss did not improve from 0.00060
# Epoch 147/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 8.0306e-05 - val_loss: 6.5392e-04
#
# Epoch 00147: val_loss did not improve from 0.00060
# Epoch 148/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.6704e-05 - val_loss: 6.4816e-04
#
# Epoch 00148: val_loss did not improve from 0.00060
# Epoch 149/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.6925e-05 - val_loss: 6.5022e-04
#
# Epoch 00149: val_loss did not improve from 0.00060
# Epoch 150/150
# 3424/3424 [==============================] - 4s 1ms/step - loss: 7.7417e-05 - val_loss: 6.4020e-04
#
# Epoch 00150: val_loss did not improve from 0.00060
